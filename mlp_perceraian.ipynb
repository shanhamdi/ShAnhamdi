# %% [markdown]
# <a href="https://colab.research.google.com/github/shanhamdi/ShAnhamdi/blob/main/mlp_perceraian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset=pd.read_csv('/content/dataset.csv')

# %%
data_input = dataset.drop(columns=['T'])
data_output = dataset['T']

data_input.head(102)
# Out:
#       x1   x2   x3   x4   x5   x6
# 0    116   90   65   83   86   63
# 1     90   65   83   86   63   24
# 2     65   83   86   63   24   72
# 3     83   86   63   24   72   78
# 4     86   63   24   72   78   51
# ..   ...  ...  ...  ...  ...  ...
# 97   131  117   57  109  177  119
# 98   117   57  109  177  119  122
# 99    57  109  177  119  122  117
# 100  109  177  119  122  117  128
# 101  177  119  122  117  128  100
#
# [102 rows x 6 columns]

# %% [markdown]
# PROSES NORMALISASI DATA

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
normalized_data = scaler.fit_transform(dataset)

# %%
df_normalized = pd.DataFrame(normalized_data, columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'T'])

# %%
df_normalized.head(103)
# Out:
#            x1        x2        x3        x4        x5        x6         T
# 0    0.556122  0.423469  0.295918  0.387755  0.403061  0.285714  0.086735
# 1    0.423469  0.295918  0.387755  0.403061  0.285714  0.086735  0.331633
# 2    0.295918  0.387755  0.403061  0.285714  0.086735  0.331633  0.362245
# 3    0.387755  0.403061  0.285714  0.086735  0.331633  0.362245  0.224490
# 4    0.403061  0.285714  0.086735  0.331633  0.362245  0.224490  0.229592
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.632653  0.561224  0.255102  0.520408  0.867347  0.571429  0.586735
# 98   0.561224  0.255102  0.520408  0.867347  0.571429  0.586735  0.561224
# 99   0.255102  0.520408  0.867347  0.571429  0.586735  0.561224  0.617347
# 100  0.520408  0.867347  0.571429  0.586735  0.561224  0.617347  0.474490
# 101  0.867347  0.571429  0.586735  0.561224  0.617347  0.474490  0.295918
#
# [102 rows x 7 columns]

# %% [markdown]
# **MEMBUAT DATA TRAINING DAN DATA TESTING**

# %%
from sklearn.model_selection import train_test_split

# %%
dataa=pd.read_csv('/content/normalisasi.csv')

# %%
x = normalized_data[:, :6]
t = normalized_data[:, 6]

# %%
x
# Out:
# array([[0.55612245, 0.42346939, 0.29591837, 0.3877551 , 0.40306122,
#         0.28571429],
#        [0.42346939, 0.29591837, 0.3877551 , 0.40306122, 0.28571429,
#         0.08673469],
#        [0.29591837, 0.3877551 , 0.40306122, 0.28571429, 0.08673469,
#         0.33163265],
#        [0.3877551 , 0.40306122, 0.28571429, 0.08673469, 0.33163265,
#         0.3622449 ],
#        [0.40306122, 0.28571429, 0.08673469, 0.33163265, 0.3622449 ,
#         0.2244898 ],
#        [0.28571429, 0.08673469, 0.33163265, 0.3622449 , 0.2244898 ,
#         0.22959184],
#        [0.08673469, 0.33163265, 0.3622449 , 0.2244898 , 0.22959184,
#         0.08673469],
#        [0.33163265, 0.3622449 , 0.2244898 , 0.22959184, 0.08673469,
#         0.45918367],
#        [0.3622449 , 0.2244898 , 0.22959184, 0.08673469, 0.45918367,
#         0.39795918],
#        [0.2244898 , 0.22959184, 0.08673469, 0.45918367, 0.39795918,
#         0.34183673],
#        [0.22959184, 0.08673469, 0.45918367, 0.39795918, 0.34183673,
# ...

# %%
t
# Out:
# array([0.08673469, 0.33163265, 0.3622449 , 0.2244898 , 0.22959184,
#        0.08673469, 0.45918367, 0.39795918, 0.34183673, 0.30612245,
#        0.39795918, 0.25510204, 0.15306122, 0.57653061, 0.37755102,
#        0.40816327, 0.30612245, 0.21938776, 0.50510204, 0.25      ,
#        0.45918367, 0.35204082, 0.40306122, 0.16836735, 0.23979592,
#        0.42857143, 0.41326531, 0.47959184, 0.38265306, 0.16836735,
#        0.55102041, 0.43877551, 0.35204082, 0.43877551, 0.27040816,
#        0.08673469, 0.46938776, 0.43367347, 0.44387755, 0.56122449,
#        0.5       , 0.24489796, 0.52040816, 0.53061224, 0.5       ,
#        0.35714286, 0.2755102 , 0.1377551 , 0.65306122, 0.47959184,
#        0.35204082, 0.47959184, 0.43367347, 0.31122449, 0.59693878,
#        0.41836735, 0.42346939, 0.42857143, 0.23469388, 0.34183673,
#        0.68877551, 0.36734694, 0.46938776, 0.5255102 , 0.31122449,
#        0.21428571, 0.75      , 0.5255102 , 0.2755102 , 0.01020408,
# ...

# %%
x_train, x_test, t_train, t_test = train_test_split(x, t, test_size=0.1, random_state=42)

# %%
x_train
# Out:
# array([[0.42857143, 0.41326531, 0.47959184, 0.38265306, 0.16836735,
#         0.55102041],
#        [0.63265306, 0.56122449, 0.25510204, 0.52040816, 0.86734694,
#         0.57142857],
#        [0.7244898 , 0.64285714, 0.37244898, 0.28571429, 0.62755102,
#         0.53061224],
#        [0.01020408, 0.70918367, 0.67346939, 0.56632653, 0.80612245,
#         0.47959184],
#        [0.40306122, 0.28571429, 0.08673469, 0.33163265, 0.3622449 ,
#         0.2244898 ],
#        [0.56632653, 0.80612245, 0.47959184, 0.5255102 , 0.        ,
#         1.        ],
#        [0.47959184, 0.38265306, 0.16836735, 0.55102041, 0.43877551,
#         0.35204082],
#        [0.45918367, 0.39795918, 0.34183673, 0.30612245, 0.39795918,
#         0.25510204],
#        [0.45918367, 0.35204082, 0.40306122, 0.16836735, 0.23979592,
#         0.42857143],
#        [0.52040816, 0.86734694, 0.57142857, 0.58673469, 0.56122449,
#         0.61734694],
#        [0.1377551 , 0.65306122, 0.47959184, 0.35204082, 0.47959184,
# ...

# %%
x_test
# Out:
# array([[0.23979592, 0.42857143, 0.41326531, 0.47959184, 0.38265306,
#         0.16836735],
#        [0.36734694, 0.46938776, 0.5255102 , 0.31122449, 0.21428571,
#         0.75      ],
#        [0.42346939, 0.42857143, 0.23469388, 0.34183673, 0.68877551,
#         0.36734694],
#        [0.24489796, 0.52040816, 0.53061224, 0.5       , 0.35714286,
#         0.2755102 ],
#        [0.46938776, 0.43367347, 0.44387755, 0.56122449, 0.5       ,
#         0.24489796],
#        [0.27040816, 0.08673469, 0.46938776, 0.43367347, 0.44387755,
#         0.56122449],
#        [0.53061224, 0.60714286, 0.57142857, 0.59183673, 0.52040816,
#         0.24489796],
#        [0.56122449, 0.5       , 0.24489796, 0.52040816, 0.53061224,
#         0.5       ],
#        [0.22959184, 0.08673469, 0.45918367, 0.39795918, 0.34183673,
#         0.30612245],
#        [0.55612245, 0.42346939, 0.29591837, 0.3877551 , 0.40306122,
#         0.28571429],
#        [0.15306122, 0.57653061, 0.37755102, 0.40816327, 0.30612245,
# ...

# %%
t_train
# Out:
# array([0.43877551, 0.58673469, 0.60714286, 0.5255102 , 0.22959184,
#        0.7244898 , 0.43877551, 0.15306122, 0.41326531, 0.4744898 ,
#        0.31122449, 0.40306122, 0.2755102 , 0.5       , 0.56122449,
#        0.40816327, 0.56632653, 0.56122449, 0.30612245, 0.53061224,
#        0.25510204, 0.29591837, 0.41836735, 0.38265306, 0.31122449,
#        0.08673469, 1.        , 0.21428571, 0.08673469, 0.30612245,
#        0.63265306, 0.27040816, 0.39795918, 0.53061224, 0.67346939,
#        0.47959184, 0.25      , 0.62755102, 0.42857143, 0.        ,
#        0.47959184, 0.57653061, 0.23979592, 0.2244898 , 0.21938776,
#        0.44387755, 0.34183673, 0.64285714, 0.45918367, 0.75      ,
#        0.46938776, 0.24489796, 0.42346939, 0.86734694, 0.59693878,
#        0.35204082, 0.01020408, 0.2755102 , 0.01020408, 0.36734694,
#        0.61734694, 0.37244898, 0.24489796, 0.23469388, 0.65306122,
#        0.52040816, 0.42857143, 0.47959184, 0.35204082, 0.57142857,
# ...

# %%
t_test
# Out:
# array([0.55102041, 0.5255102 , 0.46938776, 0.1377551 , 0.52040816,
#        0.5       , 0.97959184, 0.35714286, 0.39795918, 0.08673469,
#        0.50510204])

# %%
df_train = pd.DataFrame(x_train, columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6'])
df_train['t'] = t_train

# %%
df_test = pd.DataFrame(x_test, columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6'])
df_test['t'] = t_test

# %%
print("Data Training:")
print(df_train)
# Out:
# Data Training:
#           x1        x2        x3        x4        x5        x6         t
# 0   0.428571  0.413265  0.479592  0.382653  0.168367  0.551020  0.438776
# 1   0.632653  0.561224  0.255102  0.520408  0.867347  0.571429  0.586735
# 2   0.724490  0.642857  0.372449  0.285714  0.627551  0.530612  0.607143
# 3   0.010204  0.709184  0.673469  0.566327  0.806122  0.479592  0.525510
# 4   0.403061  0.285714  0.086735  0.331633  0.362245  0.224490  0.229592
# ..       ...       ...       ...       ...       ...       ...       ...
# 86  0.596939  0.418367  0.423469  0.428571  0.234694  0.341837  0.688776
# 87  0.214286  0.750000  0.525510  0.275510  0.010204  0.010204  0.709184
# 88  0.341837  0.306122  0.397959  0.255102  0.153061  0.576531  0.377551
# 89  0.571429  0.591837  0.520408  0.244898  0.979592  0.632653  0.561224
# 90  0.357143  0.275510  0.137755  0.653061  0.479592  0.352041  0.479592
#
# [91 rows x 7 columns]

# %%
print("Data Testing:")
print(df_test)
# Out:
# Data Testing:
#           x1        x2        x3        x4        x5        x6         t
# 0   0.239796  0.428571  0.413265  0.479592  0.382653  0.168367  0.551020
# 1   0.367347  0.469388  0.525510  0.311224  0.214286  0.750000  0.525510
# 2   0.423469  0.428571  0.234694  0.341837  0.688776  0.367347  0.469388
# 3   0.244898  0.520408  0.530612  0.500000  0.357143  0.275510  0.137755
# 4   0.469388  0.433673  0.443878  0.561224  0.500000  0.244898  0.520408
# 5   0.270408  0.086735  0.469388  0.433673  0.443878  0.561224  0.500000
# 6   0.530612  0.607143  0.571429  0.591837  0.520408  0.244898  0.979592
# 7   0.561224  0.500000  0.244898  0.520408  0.530612  0.500000  0.357143
# 8   0.229592  0.086735  0.459184  0.397959  0.341837  0.306122  0.397959
# 9   0.556122  0.423469  0.295918  0.387755  0.403061  0.285714  0.086735
# 10  0.153061  0.576531  0.377551  0.408163  0.306122  0.219388  0.505102

# %% [markdown]
# Menampilkan tabel data training

# %%
df_train.head(100)
# Out:
#           x1        x2        x3        x4        x5        x6         t
# 0   0.428571  0.413265  0.479592  0.382653  0.168367  0.551020  0.438776
# 1   0.632653  0.561224  0.255102  0.520408  0.867347  0.571429  0.586735
# 2   0.724490  0.642857  0.372449  0.285714  0.627551  0.530612  0.607143
# 3   0.010204  0.709184  0.673469  0.566327  0.806122  0.479592  0.525510
# 4   0.403061  0.285714  0.086735  0.331633  0.362245  0.224490  0.229592
# ..       ...       ...       ...       ...       ...       ...       ...
# 86  0.596939  0.418367  0.423469  0.428571  0.234694  0.341837  0.688776
# 87  0.214286  0.750000  0.525510  0.275510  0.010204  0.010204  0.709184
# 88  0.341837  0.306122  0.397959  0.255102  0.153061  0.576531  0.377551
# 89  0.571429  0.591837  0.520408  0.244898  0.979592  0.632653  0.561224
# 90  0.357143  0.275510  0.137755  0.653061  0.479592  0.352041  0.479592
#
# [91 rows x 7 columns]

# %% [markdown]
# Menampilkan tabel data testing

# %%
df_test.head(21)
# Out:
#           x1        x2        x3        x4        x5        x6         t
# 0   0.239796  0.428571  0.413265  0.479592  0.382653  0.168367  0.551020
# 1   0.367347  0.469388  0.525510  0.311224  0.214286  0.750000  0.525510
# 2   0.423469  0.428571  0.234694  0.341837  0.688776  0.367347  0.469388
# 3   0.244898  0.520408  0.530612  0.500000  0.357143  0.275510  0.137755
# 4   0.469388  0.433673  0.443878  0.561224  0.500000  0.244898  0.520408
# 5   0.270408  0.086735  0.469388  0.433673  0.443878  0.561224  0.500000
# 6   0.530612  0.607143  0.571429  0.591837  0.520408  0.244898  0.979592
# 7   0.561224  0.500000  0.244898  0.520408  0.530612  0.500000  0.357143
# 8   0.229592  0.086735  0.459184  0.397959  0.341837  0.306122  0.397959
# 9   0.556122  0.423469  0.295918  0.387755  0.403061  0.285714  0.086735
# 10  0.153061  0.576531  0.377551  0.408163  0.306122  0.219388  0.505102

# %% [markdown]
# **MEMBUAT MODEL MULTILAYER PERCEPTRON**

# %% [markdown]
# mengimpor kelas Sequential dan Dense dari pustaka keras.

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
from keras.utils import plot_model
import matplotlib.pyplot as plt
import pydot
import graphviz

# %% [markdown]
# membangun model Sequential dan menambahkan tiga lapisan Dense.

# %%
model = Sequential()
model.add(Dense(16, input_dim=6, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])

# %% [markdown]
# mengompilasi model dengan menentukan fungsi kerugian dan algoritma optimasi

# %% [markdown]
# Menampilkan model dengan tiga layer Dense.

# %%
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_42 (Dense)            (None, 16)                112
#
#  dense_43 (Dense)            (None, 8)                 136
#
#  dense_44 (Dense)            (None, 1)                 9
#
# ...
# Total params: 257
# Trainable params: 257
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Model tersebut diatas adalah sebuah Sequential model dengan tiga layer Dense.
#
# Layer pertama (dense_194) memiliki 16 output neurons dan menerima input dari layer sebelumnya (input layer atau hidden layer). Total parameter yang dimiliki oleh layer ini adalah 112, yang terdiri dari bobot (weight) dan bias.
#
# Layer kedua (dense_195) juga merupakan layer Dense dengan 8 output neurons dan menerima input dari layer sebelumnya. Total parameter yang dimiliki oleh layer ini adalah 136.
#
# Layer ketiga (dense_196) adalah layer Dense terakhir dengan 1 output neuron yang akan menghasilkan prediksi akhir. Total parameter yang dimiliki oleh layer ini adalah 9.
#
# Total parameter (257) adalah jumlah dari parameter pada semua layer.

# %% [markdown]
# Menampilkan gambar arsitektur model MLP

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Menghitung evaluasi model pada data training

# %%
train_loss = model.evaluate(x_train, t_train)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0655 - mae: 0.2050

# %% [markdown]
# Menghitung evaluasi model pada data testing

# %%
test_loss = model.evaluate(x_train, t_train)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0655 - mae: 0.2050

# %% [markdown]
# **PELATIHAN MODEL DENGAN DATA TRAINING**

# %%
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# Menghitung model data training dengan sebanyak epouch yang dilakukan

# %%
history = model.fit(x_train, t_train, validation_split=0.2, epochs=62, batch_size=10)
# Out:
# Epoch 1/62
# 8/8 [==============================] - 1s 18ms/step - loss: 0.0646 - mae: 0.2021 - val_loss: 0.0471 - val_mae: 0.1738
# Epoch 2/62
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0574 - mae: 0.1904 - val_loss: 0.0423 - val_mae: 0.1623
# Epoch 3/62
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0529 - mae: 0.1823 - val_loss: 0.0391 - val_mae: 0.1560
# Epoch 4/62
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0504 - mae: 0.1783 - val_loss: 0.0361 - val_mae: 0.1503
# Epoch 5/62
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0473 - mae: 0.1723 - val_loss: 0.0345 - val_mae: 0.1482
# Epoch 6/62
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0457 - mae: 0.1697 - val_loss: 0.0332 - val_mae: 0.1464
# Epoch 7/62
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0451 - mae: 0.1683 - val_loss: 0.0324 - val_mae: 0.1453
# Epoch 8/62
# ...

# %% [markdown]
# Menghitung model data testing dengan sebanyak epouch yang dilakukan

# %%
history = model.fit(x_test, t_test, validation_split=0.2, epochs=62, batch_size=10)
# Out:
# Epoch 1/62
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0591 - mae: 0.1796 - val_loss: 0.0413 - val_mae: 0.1420
# Epoch 2/62
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0589 - mae: 0.1793 - val_loss: 0.0415 - val_mae: 0.1421
# Epoch 3/62
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0587 - mae: 0.1787 - val_loss: 0.0417 - val_mae: 0.1424
# Epoch 4/62
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0584 - mae: 0.1780 - val_loss: 0.0420 - val_mae: 0.1426
# Epoch 5/62
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0580 - mae: 0.1770 - val_loss: 0.0424 - val_mae: 0.1430
# Epoch 6/62
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0575 - mae: 0.1759 - val_loss: 0.0428 - val_mae: 0.1434
# Epoch 7/62
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0570 - mae: 0.1747 - val_loss: 0.0432 - val_mae: 0.1438
# Epoch 8/62
# ...

# %% [markdown]
# Menampilkan grafik loss dan akurasi pada proses pelatihan data training dan testing

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Testing'], loc='upper left')
plt.show()

# %% [markdown]
# Evaluasi model fit data training

# %%
model.fit(x_train, t_train)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0414 - mae: 0.1629

# %% [markdown]
# **EVALUASI MODEL DENGAN DATA TRAINING**

# %%
train_loss = model.evaluate(x_train, t_train)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0410 - mae: 0.1621

# %% [markdown]
# **EVALUASI MODEL DENGAN DATA TESTING**

# %%
loss = model.evaluate(x_test, t_test)
# Out:
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0517 - mae: 0.1491

# %% [markdown]
# HASIL EVALUASI LOSS

# %%
print('Loss: ', loss)
# Out:
# Loss:  [0.05168517678976059, 0.1491272896528244]

# %% [markdown]
# Mengimport fungsi load_model

# %%
from keras.models import load_model

# %%
model.save('mlp_perceraian.h5')

# %% [markdown]
# Memuat kembali model yang telah disimpan sebelumnya

# %%
model = load_model('mlp_perceraian.h5')

# %%
x_test = np.array([[0.23979592, 0.42857143, 0.41326531, 0.47959184, 0.38265306,
        0.16836735],
       [0.36734694, 0.46938776, 0.5255102 , 0.31122449, 0.21428571,
        0.75      ],
       [0.42346939, 0.42857143, 0.23469388, 0.34183673, 0.68877551,
        0.36734694],
       [0.24489796, 0.52040816, 0.53061224, 0.5       , 0.35714286,
        0.2755102 ],
       [0.46938776, 0.43367347, 0.44387755, 0.56122449, 0.5       ,
        0.24489796],
       [0.27040816, 0.08673469, 0.46938776, 0.43367347, 0.44387755,
        0.56122449],
       [0.53061224, 0.60714286, 0.57142857, 0.59183673, 0.52040816,
        0.24489796],
       [0.56122449, 0.5       , 0.24489796, 0.52040816, 0.53061224,
        0.5       ],
       [0.22959184, 0.08673469, 0.45918367, 0.39795918, 0.34183673,
        0.30612245],
       [0.55612245, 0.42346939, 0.29591837, 0.3877551 , 0.40306122,
        0.28571429],
       [0.15306122, 0.57653061, 0.37755102, 0.40816327, 0.30612245,
        0.21938776]])

# %% [markdown]
# Menampilkan hasil prediksi tersebut pada output.

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 92ms/step
# [[0.49781471]
#  [0.53439844]
#  [0.49613416]
#  [0.5197595 ]
#  [0.5058705 ]
#  [0.47478634]
#  [0.52970076]
#  [0.51883125]
#  [0.47817007]
#  [0.51458406]
#  [0.51526654]]

# %% [markdown]
# Berdasarkan hasil yang diberikan, model multilayer perceptron yang dilatih dengan 91 data training dan diuji dengan 11 data testing memberikan hasil evaluasi yang cukup baik, dengan nilai loss sebesar 0.0517 dan nilai mean absolute error (MAE) sebesar 0.1491 pada data testing. Selain itu, prediksi pada output model menunjukkan nilai probabilitas perceraian pada bulan berikutnya untuk setiap input. Secara keseluruhan, hasil tersebut menunjukkan model dapat digunakan untuk memprediksi jumlah perceraian dengan cukup baik

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
